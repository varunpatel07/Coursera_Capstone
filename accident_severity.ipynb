# %% [markdown]
# <h1> this notebook will be mainly used for the capstone project<h1>

# %%
#importing libraries
import pandas as pd
import numpy as np

# %%
df=pd.read_csv(r"C:\Users\lenovo\Desktop\coursera\Data-Collisions.csv")
df.head()
# Out:
# E:\Anaconda\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (33) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    SEVERITYCODE           X          Y  OBJECTID  INCKEY  COLDETKEY REPORTNO  \
# 0             2 -122.323148  47.703140         1    1307       1307  3502005
# 1             1 -122.347294  47.647172         2   52200      52200  2607959
# 2             1 -122.334540  47.607871         3   26700      26700  1482393
# 3             1 -122.334803  47.604803         4    1144       1144  3503937
# 4             2 -122.306426  47.545739         5   17700      17700  1807429
#
#     STATUS      ADDRTYPE   INTKEY      ...      ROADCOND  \
# 0  Matched  Intersection  37475.0      ...           Wet
# 1  Matched         Block      NaN      ...           Wet
# 2  Matched         Block      NaN      ...           Dry
# ...

# %%
dft=pd.read_csv(r"C:\Users\lenovo\Desktop\coursera\Data-Collisions.csv")
dft.columns
# Out:
# E:\Anaconda\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (33) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# Index(['SEVERITYCODE', 'X', 'Y', 'OBJECTID', 'INCKEY', 'COLDETKEY', 'REPORTNO',
#        'STATUS', 'ADDRTYPE', 'INTKEY', 'LOCATION', 'EXCEPTRSNCODE',
#        'EXCEPTRSNDESC', 'SEVERITYCODE.1', 'SEVERITYDESC', 'COLLISIONTYPE',
#        'PERSONCOUNT', 'PEDCOUNT', 'PEDCYLCOUNT', 'VEHCOUNT', 'INCDATE',
#        'INCDTTM', 'JUNCTIONTYPE', 'SDOT_COLCODE', 'SDOT_COLDESC',
#        'INATTENTIONIND', 'UNDERINFL', 'WEATHER', 'ROADCOND', 'LIGHTCOND',
#        'PEDROWNOTGRNT', 'SDOTCOLNUM', 'SPEEDING', 'ST_COLCODE', 'ST_COLDESC',
#        'SEGLANEKEY', 'CROSSWALKKEY', 'HITPARKEDCAR'],
#       dtype='object')

# %%
dft["SEVERITYCODE.1"].unique()
# Out:
# array([2, 1], dtype=int64)

# %%
df.columns
# Out:
# Index(['SEVERITYCODE', 'X', 'Y', 'OBJECTID', 'INCKEY', 'COLDETKEY', 'REPORTNO',
#        'STATUS', 'ADDRTYPE', 'INTKEY', 'LOCATION', 'EXCEPTRSNCODE',
#        'EXCEPTRSNDESC', 'SEVERITYCODE.1', 'SEVERITYDESC', 'COLLISIONTYPE',
#        'PERSONCOUNT', 'PEDCOUNT', 'PEDCYLCOUNT', 'VEHCOUNT', 'INCDATE',
#        'INCDTTM', 'JUNCTIONTYPE', 'SDOT_COLCODE', 'SDOT_COLDESC',
#        'INATTENTIONIND', 'UNDERINFL', 'WEATHER', 'ROADCOND', 'LIGHTCOND',
#        'PEDROWNOTGRNT', 'SDOTCOLNUM', 'SPEEDING', 'ST_COLCODE', 'ST_COLDESC',
#        'SEGLANEKEY', 'CROSSWALKKEY', 'HITPARKEDCAR'],
#       dtype='object')

# %%
df=df.drop(['X', 'Y', 'OBJECTID', 'INCKEY', 'COLDETKEY', 'REPORTNO','EXCEPTRSNCODE','EXCEPTRSNDESC','INCDATE','INCDTTM','ST_COLCODE', 'ST_COLDESC','SEGLANEKEY', 'CROSSWALKKEY'],axis=1)

# %%
df.head()
# Out:
#    SEVERITYCODE   STATUS      ADDRTYPE   INTKEY  \
# 0             2  Matched  Intersection  37475.0
# 1             1  Matched         Block      NaN
# 2             1  Matched         Block      NaN
# 3             1  Matched         Block      NaN
# 4             2  Matched  Intersection  34387.0
#
#                                       LOCATION  SEVERITYCODE.1  \
# 0                   5TH AVE NE AND NE 103RD ST               2
# 1   AURORA BR BETWEEN RAYE ST AND BRIDGE WAY N               1
# 2  4TH AVE BETWEEN SENECA ST AND UNIVERSITY ST               1
# 3     2ND AVE BETWEEN MARION ST AND MADISON ST               1
# 4              SWIFT AVE S AND SWIFT AV OFF RP               2
#
#                      SEVERITYDESC COLLISIONTYPE  PERSONCOUNT  PEDCOUNT  \
# 0                Injury Collision        Angles            2         0
# 1  Property Damage Only Collision     Sideswipe            2         0
# 2  Property Damage Only Collision    Parked Car            4         0
# ...

# %%
df.drop(['STATUS','INTKEY', 'LOCATION','SEVERITYCODE.1','SDOT_COLCODE'],axis=1,inplace=True)

# %%
df.drop(["JUNCTIONTYPE","SDOT_COLDESC"],axis=1,inplace=True)

# %%
df.isnull().sum()
# Out:
# SEVERITYCODE           0
# ADDRTYPE            1926
# SEVERITYDESC           0
# COLLISIONTYPE       4904
# PERSONCOUNT            0
# PEDCOUNT               0
# PEDCYLCOUNT            0
# VEHCOUNT               0
# INATTENTIONIND    164868
# UNDERINFL           4884
# WEATHER             5081
# ROADCOND            5012
# LIGHTCOND           5170
# PEDROWNOTGRNT     190006
# SDOTCOLNUM         79737
# SPEEDING          185340
# HITPARKEDCAR           0
# dtype: int64

# %%
df.drop(["SPEEDING","PEDROWNOTGRNT","SDOTCOLNUM","INATTENTIONIND"],axis=1,inplace=True)

# %%
df.shape
# Out:
# (194673, 13)

# %%
df.dropna(axis=0,inplace=True)

# %%
weathers=df.groupby("WEATHER")["WEATHER"].count()

# %%
df.columns
# Out:
# Index(['SEVERITYCODE', 'ADDRTYPE', 'SEVERITYDESC', 'COLLISIONTYPE',
#        'PERSONCOUNT', 'PEDCOUNT', 'PEDCYLCOUNT', 'VEHCOUNT', 'UNDERINFL',
#        'WEATHER', 'ROADCOND', 'LIGHTCOND', 'HITPARKEDCAR'],
#       dtype='object')

# %%
df
# Out:
#         SEVERITYCODE      ADDRTYPE                    SEVERITYDESC  \
# 0                  2  Intersection                Injury Collision
# 1                  1         Block  Property Damage Only Collision
# 2                  1         Block  Property Damage Only Collision
# 3                  1         Block  Property Damage Only Collision
# 4                  2  Intersection                Injury Collision
# 5                  1  Intersection  Property Damage Only Collision
# 6                  1  Intersection  Property Damage Only Collision
# 7                  2  Intersection                Injury Collision
# 8                  1         Block  Property Damage Only Collision
# 9                  2  Intersection                Injury Collision
# 10                 1         Alley  Property Damage Only Collision
# 11                 1  Intersection  Property Damage Only Collision
# 12                 1         Block  Property Damage Only Collision
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
df2=df.copy()
le=LabelEncoder()
df2.ADDRTYPE=le.fit_transform(df2.ADDRTYPE)
df2
# Out:
#         SEVERITYCODE  ADDRTYPE                    SEVERITYDESC COLLISIONTYPE  \
# 0                  2         2                Injury Collision        Angles
# 1                  1         1  Property Damage Only Collision     Sideswipe
# 2                  1         1  Property Damage Only Collision    Parked Car
# 3                  1         1  Property Damage Only Collision         Other
# 4                  2         2                Injury Collision        Angles
# 5                  1         2  Property Damage Only Collision        Angles
# 6                  1         2  Property Damage Only Collision        Angles
# 7                  2         2                Injury Collision        Cycles
# 8                  1         1  Property Damage Only Collision    Parked Car
# 9                  2         2                Injury Collision        Angles
# 10                 1         0  Property Damage Only Collision         Other
# ...

# %%
df2.SEVERITYCODE
# Out:
# 0         2
# 1         1
# 2         1
# 3         1
# 4         2
# 5         1
# 6         1
# 7         2
# 8         1
# 9         2
# 10        1
# 11        1
# 12        1
# 13        1
# 14        2
# 16        2
# 17        1
# 18        2
# 19        1
# 20        2
# 21        2
# 22        1
# 23        1
# 24        2
# 25        2
# 26        1
# 27        1
# 28        1
# 29        1
# 30        1
#          ..
# 194640    2
# 194641    1
# 194642    1
# 194643    1
# 194644    1
# 194645    2
# 194647    2
# 194648    1
# 194649    2
# 194650    2
# 194651    1
# 194652    1
# 194653    2
# 194656    2
# 194657    1
# 194658    1
# 194659    1
# 194660    2
# 194661    2
# 194662    1
# 194663    2
# 194664    1
# 194665    1
# 194666    2
# 194667    1
# 194668    2
# 194669    1
# 194670    2
# 194671    2
# 194672    1
# Name: SEVERITYCODE, Length: 187504, dtype: int64
